# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

products = []
Prices = []
Desceiptions = []
reviews = []
headers = {"User-Agent":"Mozilla/5.0"}
for i in range (1,10):
    url = f"https://www.flipkart.com/oppo-k14-5g-icy-blue-256-gb/p/itm2a5cc1d23c2af?pid=MOBHKQYYPFBYDP3Z&lid=LSTMOBHKQYYPFBYDP3ZSQTALI&marketplace=FLIPKART&q=5g+mobile+under+50000+rupees&store=tyy%2F4io&srno=s_2_48&otracker=AS_QueryStore_OrganicAutoSuggest_1_21_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_21_na_na_na&fm=search-autosuggest&iid=bf12ae7c-4286-4f09-92dc-e915ee49ec77.MOBHKQYYPFBYDP3Z.SEARCH&ppt=sp&ppn=sp&ssid=p6tol99r5c0000001780287777380&qH=6ba18d30419f4a1a&ov_redirect=true"

    r = requests.get(url,headers = headers)
    soup = BeautifulSoup(r,text,"lxlm")
    names = soup.find_all("div",class_"RG551K")
    for i in names:
        name = i.text
        products.append(name)
    print("Products:",Products)
    price = soupc.find_all("div",class_="hZ3p6w DeU9vF")
    for i in price:
        pri = i.text
        prices.append(pri)
    print("prices: ",prices)
    Description = soup.find_all("div", class_=:"CMXw7N")
    for i in Discription:
        dis = i.text
        Discription.append(dis)
    print("Discriptions: ",Discriptions)
# Out:
#   Cell In[4], line 15
#     names = soup.find_all("div",class_"RG551K")
#                                       ^
# SyntaxError: invalid syntax
